# %% [markdown]
# ## Introduction to Probability and Statistics
# ## Assignment
#
# In this assignment, we will use the dataset of diabetes patients taken [from here](https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html).

# %% [markdown]
# ###### Install Library

# %%
pip install fitter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fitter in /usr/local/lib/python3.9/dist-packages (1.5.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from fitter) (4.65.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from fitter) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from fitter) (1.22.4)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from fitter) (8.1.3)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.9/dist-packages (from fitter) (1.10.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from fitter) (3.7.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from fitter) (1.2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fitter) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fitter) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fitter) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fitter) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fitter) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fitter) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fitter) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fitter) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fitter) (4.39.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->fitter) (2022.7.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->fitter) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->fitter) (1.16.0)

# %% [markdown]
# ###### Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

from fitter import Fitter, get_common_distributions, get_distributions
from scipy import stats

# %% [markdown]
# ###### Read Dataset

# %%
diabetes = pd.read_csv("https://www4.stat.ncsu.edu/~boos/var.select/diabetes.tab.txt",sep='\t')
diabetes
# Out:
#      AGE  SEX   BMI      BP   S1     S2    S3    S4      S5   S6    Y
# 0     59    2  32.1  101.00  157   93.2  38.0  4.00  4.8598   87  151
# 1     48    1  21.6   87.00  183  103.2  70.0  3.00  3.8918   69   75
# 2     72    2  30.5   93.00  156   93.6  41.0  4.00  4.6728   85  141
# 3     24    1  25.3   84.00  198  131.4  40.0  5.00  4.8903   89  206
# 4     50    1  23.0  101.00  192  125.4  52.0  4.00  4.2905   80  135
# ..   ...  ...   ...     ...  ...    ...   ...   ...     ...  ...  ...
# 437   60    2  28.2  112.00  185  113.8  42.0  4.00  4.9836   93  178
# 438   47    2  24.9   75.00  225  166.0  42.0  5.00  4.4427  102  104
# 439   60    2  24.9   99.67  162  106.6  43.0  3.77  4.1271   95  132
# 440   36    1  30.0   95.00  201  125.2  42.0  4.79  5.1299   85  220
# 441   36    1  19.6   71.00  250  133.2  97.0  3.00  4.5951   92   57
#
# [442 rows x 11 columns]

# %% [markdown]
# In this dataset, columns as the following:
# * Age and sex are self-explanatory
# * BMI is body mass index
# * BP is average blood pressure
# * S1 through S6 are different blood measurements
# * Y is the qualitative measure of disease progression over one year
#
# Let's study this dataset using methods of probability and statistics.
#
# ### Task 1: Compute mean values and variance for all values

# %% [markdown]
# ###### Mean

# %%
mean_values=np.mean(diabetes)
mean_values
# Out:
# AGE     48.518100
# SEX      1.468326
# BMI     26.375792
# BP      94.647014
# S1     189.140271
# S2     115.439140
# S3      49.788462
# S4       4.070249
# S5       4.641411
# S6      91.260181
# Y      152.133484
# dtype: float64

# %% [markdown]
# ###### Variance

# %%
variance_values=np.var(diabetes)
variance_values
# Out:
# AGE     171.457817
# SEX       0.248997
# BMI      19.475636
# BP      190.871586
# S1     1195.007473
# S2      922.862835
# S3      166.915093
# S4        1.661493
# S5        0.272274
# S6      131.866695
# Y      5929.884897
# dtype: float64

# %% [markdown]
# ### Task 2: Plot boxplots for BMI, BP and Y depending on gender

# %% [markdown]
# ###### BMI

# %%
sns.boxplot(x='SEX', y='BMI', data=diabetes)
plt.title('Boxplot Body Mass Index (BMI) by Gender')
plt.show()

# %% [markdown]
# ###### SUMMARY OF BMI BLOXPLOT
#
#
# ---
# *   Rata-rata berat badan yang terjangkit diabetes dari kedua gender tersebut tidak terpaut jauh, berada disekitar 25.
# *   Pada gender 1, batas bawah BMI yang terjangkit diabetes lebih pendek dibandingkan dengan batas atasnya. Sedangkan pada gender 2 yang terjangkit diabetes, antara batas atas dan batas bawah mempunyai panjang yang seimbang.
# *   Pada gender 2 walaupun BMI-nya sekitar 37-an ia sudah termasuk ke dalam outlier yang terjangkit diabetes sedangkan pada gender 2 outlier yang terjangkit diabetes sekitar 41.
# *   BMI maksimum yang terjangkit diabetes pada gender 1 lebih tinggi yaitu di sekitar 39 sedangkan gender 2 yaitu 36.

# %% [markdown]
# ###### Average Blood Pressure (BP)

# %%
sns.boxplot(x='SEX', y='BP', data=diabetes)
plt.title('Boxplot Average Blood Pressure (BP) by Gender')
plt.show()

# %% [markdown]
# ###### SUMMARY OF BP BOXPLOT
#
# ---
# *   Rata-rata tekanan darah dari kedua gender tersebut hampir terpaut jauh. Rata-rata yang terjangkit diabetes pada gender 1 lebih rendah yaitu dibawah 90 sedangkan rata rata yang terjangkit gender 2 lebih tinggi diatas 90.
# *   Dengan tekanan darah rata-rata mencapai 130-an pada gender 1, ternyata masih terdapat yang terjangkit penyakit diabetes.
# *   Minumum rata-rata tekanan darah yang terjangkit diabetes pada gender 1 lebih rendah yaitu di sekitar 61 sedangkan gender 2 di sekitar 71.

# %% [markdown]
# ###### The Qualitative Measure of Disease Progression Over One Year (Y)

# %%
plt.figure(figsize = (9,6))
sns.boxplot(x='SEX', y='Y', data=diabetes)
plt.title('Boxplot Qualitative Measure of Disease Progression Over One Year (Y) by Gender')
plt.show()

# %% [markdown]
# ###### SUMMARY OF THE QUALITATIVE MEASURE OF DISEASE PROGRESSION OVER ONE YEAR (Y)
#
#
# ---
# *   Berdasarkan tindakan kualitatif yang terjangkit diabetes pada kedua gender mempunyai rata-rata yang sama, yaitu di bawah 150.
# *   Batas bawah yang terjangkit diabetes pada gender 1 memiliki nilai di sekitar 44-95 sedangkan gender 2 disekitar 47-98. Batas atas yang terjangkit diabetes pada gender 1 memiliki nilai di sekitar 200-349 sedangkan gender 2 di sekitar 202-347.
# *   Berdasarkan tindakan kualitatif, tidak ada seorang pun yang terjangit diabetes di atas nilai minumin maupun di bawah nilai minumum dengan arti lain tidak ada outlier pada kedua gender.

# %% [markdown]
# ### Task 3: What is the the distribution of Age, Sex, BMI and Y variables?

# %% [markdown]
# ###### Read Dataset

# %%
diabetes
# Out:
#      AGE  SEX   BMI      BP   S1     S2    S3    S4      S5   S6    Y
# 0     59    2  32.1  101.00  157   93.2  38.0  4.00  4.8598   87  151
# 1     48    1  21.6   87.00  183  103.2  70.0  3.00  3.8918   69   75
# 2     72    2  30.5   93.00  156   93.6  41.0  4.00  4.6728   85  141
# 3     24    1  25.3   84.00  198  131.4  40.0  5.00  4.8903   89  206
# 4     50    1  23.0  101.00  192  125.4  52.0  4.00  4.2905   80  135
# ..   ...  ...   ...     ...  ...    ...   ...   ...     ...  ...  ...
# 437   60    2  28.2  112.00  185  113.8  42.0  4.00  4.9836   93  178
# 438   47    2  24.9   75.00  225  166.0  42.0  5.00  4.4427  102  104
# 439   60    2  24.9   99.67  162  106.6  43.0  3.77  4.1271   95  132
# 440   36    1  30.0   95.00  201  125.2  42.0  4.79  5.1299   85  220
# 441   36    1  19.6   71.00  250  133.2  97.0  3.00  4.5951   92   57
#
# [442 rows x 11 columns]

# %% [markdown]
# ###### Info Dataset

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AGE     442 non-null    int64
#  1   SEX     442 non-null    int64
#  2   BMI     442 non-null    float64
#  3   BP      442 non-null    float64
#  4   S1      442 non-null    int64
#  5   S2      442 non-null    float64
#  6   S3      442 non-null    float64
#  7   S4      442 non-null    float64
#  8   S5      442 non-null    float64
#  9   S6      442 non-null    int64
#  10  Y       442 non-null    int64
# dtypes: float64(6), int64(5)
# memory usage: 38.1 KB

# %% [markdown]
# ###### AGE

# %%
sns.set_style('white')
sns.set_context("paper")
sns.histplot(data=diabetes, x="AGE", bins = 100, discrete=True)
plt.show()

# %%
age = diabetes["AGE"].values

# %%
f = Fitter(age,
          distributions= get_common_distributions())
f.fit()
f.summary()
# Out:
# Fitting 10 distributions: 100%|██████████| 10/10 [00:04<00:00,  2.14it/s]
#          sumsquare_error         aic          bic  kl_div  ks_statistic  \
# norm            0.031237  877.309530 -4212.220242     inf      0.061591
# lognorm         0.031422  879.834327 -4203.518959     inf      0.068442
# gamma           0.031435  877.634091 -4203.328596     inf      0.067551
# chi2            0.031600  876.419088 -4201.017679     inf      0.072801
# cauchy          0.033417  928.483282 -4182.395539     inf      0.107522
#
#          ks_pvalue
# norm      0.067032
# lognorm   0.030329
# gamma     0.033783
# chi2      0.017530
# cauchy    0.000066

# %%
f.get_best(method = 'sumsquare_error')
# Out:
# {'norm': {'loc': 48.51809954751131, 'scale': 13.094190207980025}}

# %%
f.fitted_param["norm"]
# Out:
# (48.51809954751131, 13.094190207980025)

# %% [markdown]
# ###### DISTRIBUTION OF AGE
#
# ---
#
# > Pada kasus ini, digunakan distribusi yang paling banyak digunakan yaitu 10 Distribusi yang didapatkan dengan syntax "get_common_distributions()". Oleh karena itu, kita hanya akan memilih 10 distribusi tersebut yang paling cocok digunakan pada dataset age.
#
# > 10 Distribusi yang paling sering digunakan : Cauchy, Chi-Square, Exponential, Exponential Power, Gamma, Log-Normal, Normal, PowerLaw, Rayleigh, Uniform.
#
#
# > Output tabel yang ditunjukkan diatas merupakan 5 teratas distribusi terbaik yang dapat digunakan pada dataset.
#
#
# > Error pada dataset gender mempunyai nilai error yang kecil yaitu 0.031237 sehingga dapat diasumsikan baik. Karena, semakin kecil nilai sumsquare_error, semakin baik kualitas model tersebut dalam memprediksi nilai yang sesuai dengan data asli.
#
#
# Hasil yang didapatkan dalam memilih distribusi yang cocok untuk Age adalah  **DISTRIBUSI NORM**.

# %% [markdown]
# ###### SEX/GENDER

# %%
sns.set_style('white')
sns.set_context("paper")
sns.histplot(data=diabetes, x="SEX", bins = 100)
plt.show()

# %%
sex = diabetes["SEX"].values

# %%
f = Fitter(sex,
           distributions = get_common_distributions())
f.fit()
f.summary()
# Out:
# Fitting 10 distributions: 100%|██████████| 10/10 [00:05<00:00,  1.73it/s]
#           sumsquare_error         aic          bic  kl_div  ks_statistic  \
# lognorm       4068.977413  361.868310   999.441934     inf      0.531674
# exponpow      4086.876080  383.609560  1001.381946     inf      0.512826
# powerlaw      4262.961703  411.307396  1020.026951     inf      0.468326
# chi2          4529.905335  138.246643  1046.872656     inf      0.531674
# expon         4876.790102   65.808352  1073.394844     inf      0.531674
#
#               ks_pvalue
# lognorm   3.662336e-117
# exponpow  2.044344e-108
# powerlaw   2.120296e-89
# chi2      3.662314e-117
# expon     3.662300e-117

# %%
f.get_best(method='sumsquare_error')
# Out:
# {'lognorm': {'s': 6.326343939293897,
#   'loc': 0.9999999999999999,
#   'scale': 0.32254224289125555}}

# %%
f.fitted_param["lognorm"]
# Out:
# (6.326343939293897, 0.9999999999999999, 0.32254224289125555)

# %%
get_common_distributions()
# Out:
# ['cauchy',
#  'chi2',
#  'expon',
#  'exponpow',
#  'gamma',
#  'lognorm',
#  'norm',
#  'powerlaw',
#  'rayleigh',
#  'uniform']

# %% [markdown]
# ###### DISTRIBUTION OF GENDER/SEX
#
# ---
# > Pada kasus ini, digunakan distribusi yang paling banyak digunakan yaitu 10 Distribusi yang didapatkan dengan syntax "get_common_distributions()". Oleh karena itu, kita hanya akan memilih 10 distribusi tersebut yang paling cocok digunakan pada dataset gender.
#
#
# > 10 Distribusi yang paling sering digunakan : Cauchy, Chi-Square, Exponential, Exponential Power, Gamma, Log-Normal, Normal, PowerLaw, Rayleigh, Uniform.
#
#
#
# > Output tabel yang ditunjukkan diatas merupakan 5 teratas distribusi terbaik yang dapat digunakan pada dataset.
#
# > Error pada dataset gender mempunyai nilai error yang sangat besar yaitu 4068.977413 sehingga dapat diasumsikan tidak baik. Karena, semakin kecil nilai sumsquare_error, semakin baik kualitas model tersebut dalam memprediksi nilai yang sesuai dengan data asli.
#
# Hasil yang didapatkan dalam memilih distribusi yang cocok untuk Gender adalah  **DISTRIBUSI LOGNORMAL**.

# %% [markdown]
# ###### BMI

# %%
sns.set_style('white')
sns.set_context("paper")
sns.histplot(data=diabetes, x="BMI", bins = 100)
plt.show()

# %%
bmi = diabetes["BMI"].values

# %%
f = Fitter(bmi)
f.fit()
f.summary()
# Out:
# Fitting 110 distributions:   0%|          | 0/110 [00:00<?, ?it/s]WARNING:fitter.fitter:SKIPPED _fit distribution (taking more than 30 seconds)
# Fitting 110 distributions:  50%|█████     | 55/110 [00:51<01:01,  1.12s/it]WARNING:fitter.fitter:SKIPPED kstwo distribution (taking more than 30 seconds)
# Fitting 110 distributions:  66%|██████▋   | 73/110 [01:24<01:06,  1.80s/it]WARNING:fitter.fitter:SKIPPED levy_stable distribution (taking more than 30 seconds)
# Fitting 110 distributions:  79%|███████▉  | 87/110 [01:52<00:21,  1.07it/s]WARNING:fitter.fitter:SKIPPED rv_continuous distribution (taking more than 30 seconds)
# Fitting 110 distributions:  80%|████████  | 88/110 [01:53<00:15,  1.40it/s]WARNING:fitter.fitter:SKIPPED rv_histogram distribution (taking more than 30 seconds)
# Fitting 110 distributions:  87%|████████▋ | 96/110 [02:22<00:52,  3.75s/it]WARNING:fitter.fitter:SKIPPED studentized_range distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [02:59<00:00,  1.64s/it]
#            sumsquare_error         aic          bic  kl_div  ks_statistic  \
# johnsonsb         0.046578  762.702184 -4023.439001     inf      0.024042
# ncx2              0.046659  757.119960 -4022.674857     inf      0.029229
# skewnorm          0.046696  758.060722 -4028.416318     inf      0.028315
# beta              0.046721  763.239835 -4022.084789     inf      0.026293
# pearson3          0.046769  756.221608 -4027.729331     inf      0.031103
#
#            ks_pvalue
# johnsonsb   0.954954
# ncx2        0.833588
# skewnorm    0.860318
# beta        0.911951
# pearson3    0.773788

# %%
f.get_best(method = 'sumsquare_error')
# Out:
# {'johnsonsb': {'a': 1.386501096337284,
#   'b': 1.515096403693299,
#   'loc': 16.07646912367744,
#   'scale': 34.05058841222548}}

# %%
f.fitted_param['johnsonsb']
# Out:
# (1.386501096337284, 1.515096403693299, 16.07646912367744, 34.05058841222548)

# %% [markdown]
# ###### DISTRIBUTION OF BMI
#
# ---
# > Pada kasus ini, distribusi yang digunakan sebanyak 110 Distribusi atau dengan arti lain memilih semua distribusi yang terdapat di library tersebut.
#
# > Output tabel yang ditunjukkan diatas merupakan 5 teratas distribusi terbaik yang dapat digunakan pada dataset.
#
# > Error pada dataset gender mempunyai nilai error yang kecil yaitu 0.046578 sehingga dapat diasumsikan baik. Karena, semakin kecil nilai sumsquare_error, semakin baik kualitas model tersebut dalam memprediksi nilai yang sesuai dengan data asli.
#
# Hasil yang didapatkan dalam memilih distribusi yang cocok untuk BMI adalah  **DISTRIBUSI JOHNSON SB**.

# %% [markdown]
# ###### QUALITATIVE MEASURE OF DIASEASE PROGRESSION OVER ONE YEAR (Y)

# %%
sns.set_style('white')
sns.set_context("paper")
sns.histplot(data=diabetes, x="Y", bins = 100)
plt.show()

# %%
y = diabetes['Y'].values

# %%
f = Fitter(y)
f.fit()
f.summary()
# Out:
# Fitting 110 distributions:   0%|          | 0/110 [00:00<?, ?it/s]WARNING:fitter.fitter:SKIPPED _fit distribution (taking more than 30 seconds)
# Fitting 110 distributions:  50%|█████     | 55/110 [01:26<01:59,  2.17s/it]WARNING:fitter.fitter:SKIPPED kstwo distribution (taking more than 30 seconds)
# Fitting 110 distributions:  65%|██████▌   | 72/110 [01:59<00:50,  1.33s/it]WARNING:fitter.fitter:SKIPPED levy_stable distribution (taking more than 30 seconds)
# Fitting 110 distributions:  79%|███████▉  | 87/110 [02:36<00:34,  1.50s/it]WARNING:fitter.fitter:SKIPPED rv_continuous distribution (taking more than 30 seconds)
# Fitting 110 distributions:  80%|████████  | 88/110 [02:36<00:24,  1.10s/it]WARNING:fitter.fitter:SKIPPED rv_histogram distribution (taking more than 30 seconds)
# Fitting 110 distributions:  84%|████████▎ | 92/110 [02:43<00:37,  2.10s/it]WARNING:fitter.fitter:SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# Fitting 110 distributions:  85%|████████▌ | 94/110 [03:13<02:13,  8.32s/it]WARNING:fitter.fitter:SKIPPED studentized_range distribution (taking more than 30 seconds)
# Fitting 110 distributions:  95%|█████████▍| 104/110 [03:31<00:12,  2.04s/it]WARNING:fitter.fitter:SKIPPED vonmises distribution (taking more than 30 seconds)
# Fitting 110 distributions: 100%|██████████| 110/110 [04:03<00:00,  2.22s/it]
#            sumsquare_error          aic          bic  kl_div  ks_statistic  \
# triang            0.000206  1202.098511 -6425.866261     inf      0.041311
# johnsonsb         0.000214  1199.704260 -6402.022863     inf      0.040976
# skewnorm          0.000217  1217.265809 -6401.772009     inf      0.056110
# beta              0.000242  1198.532817 -6348.661105     inf      0.056467
# nakagami          0.000244          inf -6349.892216     inf      0.049281
#
#            ks_pvalue
# triang      0.426223
# johnsonsb   0.436485
# skewnorm    0.119050
# beta        0.114865
# nakagami    0.225789

# %%
f.get_best(method = 'sumsquare_error')
# Out:
# {'triang': {'c': 0.12134314084107695,
#   'loc': 23.311237599328184,
#   'scale': 335.31983859453794}}

# %%
f.fitted_param['triang']
# Out:
# (0.12134314084107695, 23.311237599328184, 335.31983859453794)

# %% [markdown]
# ###### DISTRIBUTION OF QUALITATIVE MEASURE OF DIASEASE PROGRESSION OVER ONE YEAR (Y)
#
# ---
# > Pada kasus ini, distribusi yang digunakan sebanyak 110 Distribusi atau dengan arti lain memilih semua distribusi yang terdapat di library tersebut.
#
# > Output tabel yang ditunjukkan diatas merupakan 5 teratas distribusi terbaik yang dapat digunakan pada dataset.
#
#
# > Error pada dataset gender mempunyai nilai error yang kecil yaitu 0.000206 sehingga dapat diasumsikan baik. Karena, semakin kecil nilai sumsquare_error, semakin baik kualitas model tersebut dalam memprediksi nilai yang sesuai dengan data asli.
#
#
#
# Hasil yang didapatkan dalam memilih distribusi yang cocok untuk THE QUALITATIVE MEASURE OF DIASEASE PROGRESSION OVER ONE YEAR (Y) adalah  **DISTRIBUSI TRIANG**.

# %% [markdown]
# #### REFERENCE
#
# [Library Fitter about Distributions](https://medium.com/the-researchers-guide/finding-the-best-distribution-that-fits-your-data-using-pythons-fitter-library-319a5a0972e9)
